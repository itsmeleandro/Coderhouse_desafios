# %%
import numpy as np
import pandas as pd

# %%
#Crear un array de 100 numeros y calcular su mediana
arr=np.arange(1,101)
np.median(arr) #mediana
# Out:
# 50.5

# %%
#facotrial de un numero usando numpy
x=5
np.math.factorial(x) #math es el metodo para operaciones matemarticas
# Out:
# 120

# %%
#función para calcular la suma de una serie comenzando por un número cualquiera y terminando en otro número que debe ser mayor al primero

def sumatoria(a,b): 
    if (a>b or a==b):
        print("a es mayor o igual que b, no se puede efectual la sumatoria")
    else:
        z=np.arange(a,b)
        x= np.sum(z)
        return x

# %%
#aca se llama a la funcion pasando parametros
a=1; b=21
sumatoria(a,b)
# Out:
# 210

# %%
#en mi caso voy a cargar mi data frame desde el archivo local en mi pc

df=pd.read_csv('Salarios Openqube - 2020.02.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#            Timestamp Me identifico  Tengo Estoy trabajando en  \
# 0   7/6/2020 9:56:02         Mujer     26           Argentina
# 1   7/6/2020 9:57:09        Hombre     29           Argentina
# 2   7/6/2020 9:58:09         Mujer     22           Argentina
# 3   7/6/2020 9:59:52        Hombre     39           Argentina
# 4  7/6/2020 10:01:27        Hombre     32           Argentina
#
#             Dónde estás trabajando Bolivia Chile Colombia Cuba Costa Rica  \
# 0  Ciudad Autónoma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
# 1                       Corrientes     NaN   NaN      NaN  NaN        NaN
# 2  Ciudad Autónoma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
# 3                       Corrientes     NaN   NaN      NaN  NaN        NaN
# 4  Ciudad Autónoma de Buenos Aires     NaN   NaN      NaN  NaN        NaN
#
#   Ecuador El Salvador Guatemala Honduras México Nicaragua Panamá Paraguay  \
# ...

# %%
#Calculando la mediana del salario mensual
df['Salario mensual BRUTO (en tu moneda local)'].median()
# Out:
# 95000.0

# %%
##Calculando la mediana del salario mensual
df['Salario mensual BRUTO (en tu moneda local)'].mean()
# Out:
# 2992143846.202422

# %%
df['Salario mensual BRUTO (en tu moneda local)'].describe() 
#de esta forma puedo comparar las propiedades estadisticass de las columnas.
#en este caso el metodo de *describe()* los muestra con notacion cientifica/exponencial
# Out:
# count    6.415000e+03
# mean     2.992144e+09
# std      2.396308e+11
# min      1.000000e+00
# 25%      6.000000e+04
# 50%      9.500000e+04
# 75%      1.470000e+05
# max      1.919292e+13
# Name: Salario mensual BRUTO (en tu moneda local), dtype: float64

# %% [markdown]
# La mediana es menor que la media, ya que la mediana es el numero que separa a la mitad al conjunto de valores
# la media es mayor y es el promedio del conjunto de valores. En ambos casos el conjunto de valores es la columna.
